# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/spring_2023_vail-AMSGarcia12/blob/main/Day_10/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Day 10 Objectives:
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd 
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/' 
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])
    
    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history
  
def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split() 
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1] 
    return " ".join(clean_words) 

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)
    
    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }
    
    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u 
! mkdir input/ 
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))  
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 110MB/s]
# Epoch 1/20
# 24/24 [==============================] - 7s 216ms/step - loss: 0.8862 - accuracy: 0.6115 - val_loss: 0.7472 - val_accuracy: 0.6563
# Epoch 2/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6399 - accuracy: 0.7279 - val_loss: 0.5906 - val_accuracy: 0.7815
# Epoch 3/20
# 24/24 [==============================] - 3s 106ms/step - loss: 0.4856 - accuracy: 0.8240 - val_loss: 0.5226 - val_accuracy: 0.7997
# Epoch 4/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.3921 - accuracy: 0.8567 - val_loss: 0.5109 - val_accuracy: 0.8050
# Epoch 5/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.3300 - accuracy: 0.8829 - val_loss: 0.5320 - val_accuracy: 0.7906
# Epoch 6/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2815 - accuracy: 0.8990 - val_loss: 0.5446 - val_accuracy: 0.7974
# Epoch 7/20
# 24/24 [==============================] - 2s 69ms/step - loss: 0.2426 - accuracy: 0.9163 - val_loss: 0.5667 - val_accuracy: 0.7898
# Epoch 8/20
# 24/24 [==============================] - 2s 85ms/step - loss: 0.2095 - accuracy: 0.9292 - val_loss: 0.6082 - val_accuracy: 0.7876
# Epoch 9/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.1821 - accuracy: 0.9392 - val_loss: 0.6369 - val_accuracy: 0.7731
# Epoch 10/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.1594 - accuracy: 0.9481 - val_loss: 0.6722 - val_accuracy: 0.7731
# Epoch 11/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.1404 - accuracy: 0.9549 - val_loss: 0.7035 - val_accuracy: 0.7731
# Epoch 12/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1238 - accuracy: 0.9589 - val_loss: 0.7433 - val_accuracy: 0.7762
# Epoch 13/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1088 - accuracy: 0.9660 - val_loss: 0.7795 - val_accuracy: 0.7633
# Epoch 14/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0973 - accuracy: 0.9702 - val_loss: 0.8047 - val_accuracy: 0.7777
# Epoch 15/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0858 - accuracy: 0.9737 - val_loss: 0.8483 - val_accuracy: 0.7769
# Epoch 16/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0779 - accuracy: 0.9760 - val_loss: 0.8934 - val_accuracy: 0.7769
# Epoch 17/20
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0698 - accuracy: 0.9798 - val_loss: 0.9227 - val_accuracy: 0.7747
# Epoch 18/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0627 - accuracy: 0.9813 - val_loss: 0.9665 - val_accuracy: 0.7754
# Epoch 19/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0578 - accuracy: 0.9821 - val_loss: 1.0148 - val_accuracy: 0.7724
# Epoch 20/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0524 - accuracy: 0.9839 - val_loss: 1.0522 - val_accuracy: 0.7678
# Minimum validation loss reached in epoch 4
# Epoch 1/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.9668 - accuracy: 0.6191 - val_loss: 0.8801 - val_accuracy: 0.6267
# Epoch 2/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.8091 - accuracy: 0.6464 - val_loss: 0.7800 - val_accuracy: 0.6593
# Epoch 3/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.7165 - accuracy: 0.6854 - val_loss: 0.7154 - val_accuracy: 0.6980
# Epoch 4/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.6496 - accuracy: 0.7244 - val_loss: 0.6662 - val_accuracy: 0.7208
# Epoch 5/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.5946 - accuracy: 0.7638 - val_loss: 0.6271 - val_accuracy: 0.7549
# Epoch 6/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.5488 - accuracy: 0.7962 - val_loss: 0.5957 - val_accuracy: 0.7807
# Epoch 7/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5101 - accuracy: 0.8232 - val_loss: 0.5712 - val_accuracy: 0.7906
# Epoch 8/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.4768 - accuracy: 0.8393 - val_loss: 0.5520 - val_accuracy: 0.7914
# Epoch 9/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.4480 - accuracy: 0.8525 - val_loss: 0.5377 - val_accuracy: 0.7982
# Epoch 10/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.4233 - accuracy: 0.8577 - val_loss: 0.5266 - val_accuracy: 0.8020
# Epoch 11/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.4016 - accuracy: 0.8664 - val_loss: 0.5194 - val_accuracy: 0.8035
# Epoch 12/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.3824 - accuracy: 0.8725 - val_loss: 0.5147 - val_accuracy: 0.8065
# Epoch 13/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.3653 - accuracy: 0.8792 - val_loss: 0.5120 - val_accuracy: 0.8073
# Epoch 14/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.3499 - accuracy: 0.8846 - val_loss: 0.5092 - val_accuracy: 0.8050
# Epoch 15/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.3354 - accuracy: 0.8891 - val_loss: 0.5090 - val_accuracy: 0.7967
# Epoch 16/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.3220 - accuracy: 0.8941 - val_loss: 0.5101 - val_accuracy: 0.8005
# Epoch 17/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.3100 - accuracy: 0.8972 - val_loss: 0.5107 - val_accuracy: 0.7997
# Epoch 18/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2984 - accuracy: 0.9023 - val_loss: 0.5134 - val_accuracy: 0.7989
# Epoch 19/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2877 - accuracy: 0.9050 - val_loss: 0.5160 - val_accuracy: 0.8012
# Epoch 20/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2779 - accuracy: 0.9086 - val_loss: 0.5184 - val_accuracy: 0.8042
# Minimum validation loss reached in epoch 15

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                640064
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0240 - accuracy: 0.6195 - val_loss: 0.8875 - val_accuracy: 0.6669
# Epoch 2/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.7901 - accuracy: 0.7269 - val_loss: 0.7508 - val_accuracy: 0.7610
# Epoch 3/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6508 - accuracy: 0.8097 - val_loss: 0.6730 - val_accuracy: 0.7944
# Epoch 4/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.5542 - accuracy: 0.8458 - val_loss: 0.6397 - val_accuracy: 0.7989
# Epoch 5/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.4905 - accuracy: 0.8716 - val_loss: 0.6380 - val_accuracy: 0.8005
# Epoch 6/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.4450 - accuracy: 0.8872 - val_loss: 0.6418 - val_accuracy: 0.7929
# Epoch 7/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.4103 - accuracy: 0.8979 - val_loss: 0.6447 - val_accuracy: 0.7959
# Epoch 8/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.3815 - accuracy: 0.9081 - val_loss: 0.6603 - val_accuracy: 0.8050
# Epoch 9/20
# 24/24 [==============================] - 2s 62ms/step - loss: 0.3590 - accuracy: 0.9175 - val_loss: 0.6820 - val_accuracy: 0.7967
# Epoch 10/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.3398 - accuracy: 0.9242 - val_loss: 0.7002 - val_accuracy: 0.7777
# Epoch 11/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3230 - accuracy: 0.9307 - val_loss: 0.7079 - val_accuracy: 0.7883
# Epoch 12/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.3078 - accuracy: 0.9359 - val_loss: 0.7519 - val_accuracy: 0.7868
# Epoch 13/20
# 24/24 [==============================] - 2s 71ms/step - loss: 0.2955 - accuracy: 0.9412 - val_loss: 0.7371 - val_accuracy: 0.7716
# Epoch 14/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.2830 - accuracy: 0.9475 - val_loss: 0.7513 - val_accuracy: 0.7853
# Epoch 15/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2731 - accuracy: 0.9488 - val_loss: 0.7522 - val_accuracy: 0.7731
# Epoch 16/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.2626 - accuracy: 0.9530 - val_loss: 0.7783 - val_accuracy: 0.7868
# Epoch 17/20
# 24/24 [==============================] - 2s 81ms/step - loss: 0.2544 - accuracy: 0.9556 - val_loss: 0.7903 - val_accuracy: 0.7671
# Epoch 18/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.2477 - accuracy: 0.9585 - val_loss: 0.7975 - val_accuracy: 0.7815
# Epoch 19/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.2408 - accuracy: 0.9596 - val_loss: 0.8003 - val_accuracy: 0.7709
# Epoch 20/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2337 - accuracy: 0.9633 - val_loss: 0.7988 - val_accuracy: 0.7815
# Minimum validation loss reached in epoch 5

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %%
weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    reg = tf.reduce_sum(tf.abs(weights))
    return reg

print(l1_norm(weights))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d08c9cef95f1> in <module>
#       5     return reg
#       6
# ----> 7 print(l1_norm(weights))
#
# <ipython-input-6-d08c9cef95f1> in l1_norm(weights)
#       3 def l1_norm(weights):
#       4     # Enter your code here
# ----> 5     return reg
#       6
#       7 print(l1_norm(weights))
#
# NameError: name 'reg' is not defined

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    reg = tf.reduce_sum(tf.abs(weights))
    return reg

print(l1_norm(weights))
# Out:
# tf.Tensor(15, shape=(), dtype=int32)

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    reg = tf.reduce_sum(tf.square(weights))
    return reg

print(l2_norm(weights))
# Out:
# tf.Tensor(55, shape=(), dtype=int32)

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    reg = tf.reduce_sum(tf.square(weights))
    return reg

print(l2_norm(weights))
# Out:
# tf.Tensor(55, shape=(), dtype=int32)

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 4s 117ms/step - loss: 0.9124 - accuracy: 0.6041 - val_loss: 0.7804 - val_accuracy: 0.6244
# Epoch 2/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.7341 - accuracy: 0.6582 - val_loss: 0.6784 - val_accuracy: 0.7109
# Epoch 3/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.6229 - accuracy: 0.7483 - val_loss: 0.5942 - val_accuracy: 0.7853
# Epoch 4/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.5432 - accuracy: 0.8021 - val_loss: 0.5553 - val_accuracy: 0.7997
# Epoch 5/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.4847 - accuracy: 0.8243 - val_loss: 0.5322 - val_accuracy: 0.8005
# Epoch 6/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.4369 - accuracy: 0.8425 - val_loss: 0.5224 - val_accuracy: 0.8012
# Epoch 7/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3914 - accuracy: 0.8597 - val_loss: 0.5292 - val_accuracy: 0.8020
# Epoch 8/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.3646 - accuracy: 0.8712 - val_loss: 0.5370 - val_accuracy: 0.8012
# Epoch 9/20
# 24/24 [==============================] - 2s 82ms/step - loss: 0.3316 - accuracy: 0.8822 - val_loss: 0.5418 - val_accuracy: 0.7959
# Epoch 10/20
# 24/24 [==============================] - 2s 79ms/step - loss: 0.3089 - accuracy: 0.8939 - val_loss: 0.5617 - val_accuracy: 0.7974
# Epoch 11/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2804 - accuracy: 0.9037 - val_loss: 0.5836 - val_accuracy: 0.7951
# Epoch 12/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2591 - accuracy: 0.9117 - val_loss: 0.6059 - val_accuracy: 0.7921
# Epoch 13/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2408 - accuracy: 0.9209 - val_loss: 0.6071 - val_accuracy: 0.7929
# Epoch 14/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2274 - accuracy: 0.9244 - val_loss: 0.6306 - val_accuracy: 0.7967
# Epoch 15/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2057 - accuracy: 0.9304 - val_loss: 0.6497 - val_accuracy: 0.7936
# Epoch 16/20
# 24/24 [==============================] - 2s 80ms/step - loss: 0.1926 - accuracy: 0.9357 - val_loss: 0.6770 - val_accuracy: 0.7944
# Epoch 17/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.1829 - accuracy: 0.9427 - val_loss: 0.6881 - val_accuracy: 0.7967
# Epoch 18/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.1697 - accuracy: 0.9439 - val_loss: 0.6957 - val_accuracy: 0.7951
# Epoch 19/20
# 24/24 [==============================] - 2s 68ms/step - loss: 0.1629 - accuracy: 0.9513 - val_loss: 0.7199 - val_accuracy: 0.7944
# Epoch 20/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.1447 - accuracy: 0.9521 - val_loss: 0.7330 - val_accuracy: 0.7936
# Minimum validation loss reached in epoch 6

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 14s 562ms/step - loss: 1.5018 - accuracy: 0.5924 - val_loss: 1.0507 - val_accuracy: 0.6206
# Epoch 2/20
# 24/24 [==============================] - 11s 449ms/step - loss: 3.9253 - accuracy: 0.6898 - val_loss: 10.1742 - val_accuracy: 0.7124
# Epoch 3/20
# 24/24 [==============================] - 9s 362ms/step - loss: 6.7423 - accuracy: 0.7317 - val_loss: 9.5249 - val_accuracy: 0.7519
# Epoch 4/20
# 24/24 [==============================] - 7s 302ms/step - loss: 6.1785 - accuracy: 0.7653 - val_loss: 10.0427 - val_accuracy: 0.7352
# Epoch 5/20
# 24/24 [==============================] - 9s 358ms/step - loss: 7.3881 - accuracy: 0.7650 - val_loss: 8.6183 - val_accuracy: 0.7360
# Epoch 6/20
# 24/24 [==============================] - 9s 359ms/step - loss: 7.0511 - accuracy: 0.7753 - val_loss: 1.3182 - val_accuracy: 0.7253
# Epoch 7/20
# 24/24 [==============================] - 7s 307ms/step - loss: 6.4334 - accuracy: 0.7769 - val_loss: 1.5244 - val_accuracy: 0.7344
# Epoch 8/20
# 24/24 [==============================] - 8s 357ms/step - loss: 7.0433 - accuracy: 0.7726 - val_loss: 11.8769 - val_accuracy: 0.7132
# Epoch 9/20
# 24/24 [==============================] - 7s 313ms/step - loss: 7.0630 - accuracy: 0.6474 - val_loss: 10.2347 - val_accuracy: 0.6206
# Epoch 10/20
# 24/24 [==============================] - 8s 342ms/step - loss: 7.3011 - accuracy: 0.6287 - val_loss: 2.9384 - val_accuracy: 0.6351
# Epoch 11/20
# 24/24 [==============================] - 10s 401ms/step - loss: 4.4354 - accuracy: 0.6269 - val_loss: 2.9084 - val_accuracy: 0.6404
# Epoch 12/20
# 24/24 [==============================] - 8s 313ms/step - loss: 6.0682 - accuracy: 0.6198 - val_loss: 2.9145 - val_accuracy: 0.6426
# Epoch 13/20
# 24/24 [==============================] - 9s 359ms/step - loss: 6.6968 - accuracy: 0.6203 - val_loss: 2.9328 - val_accuracy: 0.6388
# Epoch 14/20
# 24/24 [==============================] - 9s 370ms/step - loss: 7.5659 - accuracy: 0.6230 - val_loss: 4.1862 - val_accuracy: 0.6358
# Epoch 15/20
# 24/24 [==============================] - 7s 304ms/step - loss: 8.3781 - accuracy: 0.6257 - val_loss: 3.8134 - val_accuracy: 0.6373
# Epoch 16/20
# 24/24 [==============================] - 9s 356ms/step - loss: 8.2798 - accuracy: 0.6238 - val_loss: 3.6242 - val_accuracy: 0.6373
# Epoch 17/20
# 24/24 [==============================] - 7s 313ms/step - loss: 8.5106 - accuracy: 0.6227 - val_loss: 11.1028 - val_accuracy: 0.6305
# Epoch 18/20
# 24/24 [==============================] - 8s 326ms/step - loss: 9.0638 - accuracy: 0.6256 - val_loss: 10.3270 - val_accuracy: 0.6313
# Epoch 19/20
# 24/24 [==============================] - 8s 355ms/step - loss: 9.7229 - accuracy: 0.6288 - val_loss: 10.1753 - val_accuracy: 0.6206
# Epoch 20/20
# 24/24 [==============================] - 7s 300ms/step - loss: 9.6626 - accuracy: 0.6285 - val_loss: 10.1703 - val_accuracy: 0.6206
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?
#
# Dropout minimizes the network reliance on particular nodes by randomly dropping them out. This takes care of noise from the distribution.
#
# L2 Regularization helps generalize the model, which helps prevent the model from overfitting.

# %% [markdown]
# ### Answer 3
#
# Dropout noise--or multiplicative noise from any distribution, as long as it has the right scale--should be used when one suspects there are redundant features. This is the case for most raw signals (such as pixels). A big network will have a penchant for overfitting, which in some sense means it will represent spurious patterns in its hidden units that are similar to redundant input features. Thus, Dropout is usually applied to input and hidden layers.
#
# Assuming asymptotics kick in, Dropout is equivalent to L2 regularization scaled by the inverse Fisher information, but this is only up to a Taylor's expansion. The expansion is exact for linear models, meaning Dropout is like regularizing with R = WXT XWT (where WWT would be vanilla L2).
#
# If no regularization does better, to paraphrase Hinton: make your net big enough that it overfits, then apply Dropout.
#
# The number of datapoints is not enough information to know whether you need Dropout. Their dimensionality and sparsity matters. For instance, Dropout helps on MNIST, which is 50,000x784 but probably wouldn't help on a dataset of size 50,000x10.
#
# In this case it did not uniformly help regularize the data at all.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/4
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1458 - accuracy: 0.9632
# Epoch 2/4
# 26/26 [==============================] - 2s 93ms/step - loss: 0.1031 - accuracy: 0.9718
# Epoch 3/4
# 26/26 [==============================] - 3s 99ms/step - loss: 0.0829 - accuracy: 0.9775
# Epoch 4/4
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0693 - accuracy: 0.9797
# 46/46 [==============================] - 0s 8ms/step - loss: 0.9948 - accuracy: 0.7739
#
# Test accuracy: 77.39%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/15
# 26/26 [==============================] - 2s 82ms/step - loss: 0.2936 - accuracy: 0.9007
# Epoch 2/15
# 26/26 [==============================] - 2s 81ms/step - loss: 0.2830 - accuracy: 0.9036
# Epoch 3/15
# 26/26 [==============================] - 2s 66ms/step - loss: 0.2730 - accuracy: 0.9071
# Epoch 4/15
# 26/26 [==============================] - 2s 63ms/step - loss: 0.2637 - accuracy: 0.9118
# Epoch 5/15
# 26/26 [==============================] - 2s 60ms/step - loss: 0.2549 - accuracy: 0.9139
# Epoch 6/15
# 26/26 [==============================] - 2s 62ms/step - loss: 0.2468 - accuracy: 0.9167
# Epoch 7/15
# 26/26 [==============================] - 2s 66ms/step - loss: 0.2391 - accuracy: 0.9198
# Epoch 8/15
# 26/26 [==============================] - 1s 41ms/step - loss: 0.2315 - accuracy: 0.9235
# Epoch 9/15
# 26/26 [==============================] - 1s 34ms/step - loss: 0.2242 - accuracy: 0.9248
# Epoch 10/15
# 26/26 [==============================] - 1s 39ms/step - loss: 0.2176 - accuracy: 0.9278
# Epoch 11/15
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2109 - accuracy: 0.9299
# Epoch 12/15
# 26/26 [==============================] - 1s 39ms/step - loss: 0.2048 - accuracy: 0.9328
# Epoch 13/15
# 26/26 [==============================] - 1s 28ms/step - loss: 0.1989 - accuracy: 0.9345
# Epoch 14/15
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1931 - accuracy: 0.9376
# Epoch 15/15
# 26/26 [==============================] - 1s 28ms/step - loss: 0.1876 - accuracy: 0.9384
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5788 - accuracy: 0.7971
#
# Test accuracy: 79.71%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1s 56ms/step - loss: 0.2855 - accuracy: 0.9452
# Epoch 2/5
# 26/26 [==============================] - 1s 53ms/step - loss: 0.2594 - accuracy: 0.9527
# Epoch 3/5
# 26/26 [==============================] - 1s 54ms/step - loss: 0.2432 - accuracy: 0.9587
# Epoch 4/5
# 26/26 [==============================] - 1s 52ms/step - loss: 0.2350 - accuracy: 0.9613
# Epoch 5/5
# 26/26 [==============================] - 2s 69ms/step - loss: 0.2240 - accuracy: 0.9645
# 46/46 [==============================] - 0s 5ms/step - loss: 0.7872 - accuracy: 0.7848
#
# Test accuracy: 78.48%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 1s 56ms/step - loss: 0.1985 - accuracy: 0.9378
# Epoch 2/6
# 26/26 [==============================] - 1s 55ms/step - loss: 0.1803 - accuracy: 0.9427
# Epoch 3/6
# 26/26 [==============================] - 2s 59ms/step - loss: 0.1674 - accuracy: 0.9460
# Epoch 4/6
# 26/26 [==============================] - 1s 54ms/step - loss: 0.1521 - accuracy: 0.9534
# Epoch 5/6
# 26/26 [==============================] - 5s 178ms/step - loss: 0.1420 - accuracy: 0.9547
# Epoch 6/6
# 26/26 [==============================] - 3s 132ms/step - loss: 0.1360 - accuracy: 0.9577
# 46/46 [==============================] - 0s 5ms/step - loss: 0.7919 - accuracy: 0.7883
#
# Test accuracy: 78.83%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus question: Plot the same for L1 regularization

# %%
cost = #Enter your code here
l1_penalty = #Enter your code here
cost_plus_l2 = #Enter your code here

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()
# Out:
#   File "<ipython-input-27-ee2ea653d151>", line 1
#     cost = #Enter your code here
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l1_penalty = lambda w: np.sum(np.abs(w))
cost_plus_l1 = lambda w: cost(w) + 5*l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# \<*Type your answer here*\>

# %% [markdown]
# # **Upload this Day 9 Colab Notebook to your Github repository under "Day 9" folder. Also add your *Reflection* on today's learning in README.md**
